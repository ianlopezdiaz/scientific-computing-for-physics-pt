# %% [markdown]
# # 02 - Fundamentos de Python

# %% [markdown]
# ## 1. Motivação Física
# _(placeholder)_

# %% [markdown]
# ## 2. Teoria
# _(placeholder)_

# %% [markdown]
# ## 3. Solução Analítica
# _(placeholder)_

# %% [markdown]
# ## 4. Implementação Numérica
# _(placeholder)_

# %%
import numpy as np

# %% [markdown]
# ## 5. Visualização
# _(placeholder)_

# %% [markdown]
# ## 6. Exercícios
# _(placeholder)_

# %% [markdown]
# ## 7. Extensões
# _(placeholder)_
